# %% [markdown]
# # Etude de l'evolution de l'électrolyte dans une sturcture poreuse
#
# ---------------------------------------------------
# Ce notebook rend compte de la modélisation de la vitesse et du temps de remplissage de l'electrolyte pour structures non-calendrées, en fonction de la configuration en un réseau de pores de cette même électrode. L'ensemble des données est issu de simulations $\textit{LBM}$ pré-traité sous Python.
#
# ------------------------------------------------------------
# <br>
# L'étude tient compte de l'analyse quantitative des données récoltées afin de construire une base de données permettant la modélisation via un réseau de neurones multi-couches, dit $\textit{Multi-Layers Perceptron}$
# Le but est alors de pouvoir utiliser le modèle entrainé pour prédire la vitesse et temps de remplissage l'électrolyte pour des structures totalement nouvelles, évitant ainsi le calcule de simulations extrêmement couteuses en termes de ressources informatiques.

# %% [markdown]
# ##### Ressources Python

# %%
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import initializers
import matplotlib.gridspec as gridspec
from sklearn.metrics import r2_score
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from scipy.stats import boxcox
from scipy import interpolate
from tensorflow import keras
from sklearn import metrics
import tensorflow as tf
import pandas as pd
import numpy as np
import warnings
import random
import pickle
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Chargement des données nécessaires

# %%
with open('./ressources/Y.pkl', 'rb') as f:
    y = pickle.load(f)
with open('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/x-REAL.pkl', 'rb') as f:
    X = pickle.load(f)

# %%
y = []
for path in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'):
    for file in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"):

        if 'saturation' in file:

            with open('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"+file, 'rb') as f:
                saturation = pickle.load(f).iloc[:,1:]

            for col in range(saturation.shape[1]):

                t0=next((i for i,
                         x in enumerate(saturation.iloc[:,col]) if abs(x-saturation.iloc[0,col]) >= 0.05),
                        None)
                t1=next((i for i, 
                         x in enumerate(saturation.iloc[:,col]) if abs(x-saturation.iloc[-1,col]) <= 0.05),None)
                if saturation.iloc[-1,col] >= 0.99:
                    out=1
                else:
                    out=0

                try:

                    y.append([t0, t1, out, saturation.iloc[t1,col],
                                     (saturation.iloc[t1,col] - saturation.iloc[t0,col]) / (t1-t0)])
                except:

                    y.append([t0, t1, out, saturation.iloc[-1,col], "Error"])

y = pd.DataFrame(y)

# %% [markdown]
# ##### Transformation des données

# %%
X['Y0'] = y.iloc[:, 0]
X['Y1'] = y.iloc[:, 4]
X['Y2'] = y.iloc[:, 1]
X['Y3'] = y.iloc[:, 3]

idx=[]
for i in range(X.shape[0]):
    if "nan" != str(X.iloc[i,7]):
        idx.append(i)
X = X.iloc[idx, :]
X=X[X['Y1'] != "Error"]

# %%
old_version1, old_version2, old_version3 = X['Y1'].copy(), X['Y2'].copy(), X['Y0'].copy()

X['Y0'] = [np.log(i) for i in X['Y0']]
X['Y1'] = [np.log(i) for i in X['Y1']]
minval = min(X['Y1'])
X['Y1'] = [i+abs(minval) for i in X['Y1']]
X['Y2'] = [np.log(i) for i in X['Y2']]

# %% [markdown]
# La distribution des valeurs de sortie est hétéroscdastique, ce qui induit un biais dans la modélisation. Une transformation des données par le processus de $\textit{Box-Cox}$ [1] permet à la variable $V_0$, $t_0$ et $t_1$ d'être assimilée à une distribution plus homoscédastique. Cela permet à la modélisation de mieux assimiler les eccarts de sorties à faibles valeurs, qu'à hautes valeurs.
# Cependant, la transformation pour la vélocité sera simplement shiftée à 0 afin de construire un réseau de neurones avec une fonction d'activation dite $\textit{LeakyReLU}$ en sortie, qui se révèle extrêment efficace lors de la prédiction.

# %%
plt.style.use("default")
fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(hspace = .25, wspace=.19)
gs1 = gridspec.GridSpec(3, 2)
axs = []

axs.append(fig.add_subplot(gs1[1]))
ax = plt.gca()b
ax.set_facecolor('xkcd:light grey')
_=ax.hist(X['Y1'], bins=100, color='mediumblue')
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=12)
_=plt.xlabel('Valeurs de $Y_{mod}$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')
axs.append(fig.add_subplot(gs1[0]))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
_=ax.hist(old_version1, bins=100, color='mediumblue')
_=plt.yticks(fontsize=12)
_=plt.xticks(fontsize=12)
_=plt.xlabel('Valeurs de $V_0$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')
axs.append(fig.add_subplot(gs1[3]))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
_=ax.hist(X['Y2'], bins=100, color='mediumblue')
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=12)
_=plt.xlabel('Valeurs de $t_{mod}$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')
axs.append(fig.add_subplot(gs1[2]))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
_=ax.hist(old_version2, bins=100, color='mediumblue')
_=plt.yticks(fontsize=12)
_=plt.xticks(fontsize=12)
_=plt.xlabel('Valeurs de $t_1$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')
axs.append(fig.add_subplot(gs1[5]))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
_=ax.hist(X['Y0'], bins=100, color='mediumblue')
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=12)
_=plt.xlabel('Valeurs de $t_{mod}$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')
axs.append(fig.add_subplot(gs1[4]))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
_=ax.hist(old_version3, bins=100, color='mediumblue')
_=plt.yticks(fontsize=12)
_=plt.xticks(fontsize=12)
_=plt.xlabel('Valeurs de $t_0$', fontweight='bold')
_=plt.ylabel('Fréquences', fontweight='bold')

# %% [markdown]
# ##### Mise en place de l'entrainement du réseau de neurones

# %% [markdown]
# Pour la base d'entrainement, les données sont standardiser afin de réduire les eccarts de valeurs pour les données dites $\textit{inputs}$. C'est à dire que toutes les entrées ont le même ordre de grandeur.<br> On applique enfin cette transformation sur la base de test également.

# %%
Train, Test = train_test_split(X[['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Ratio', 'Centre', 'Y0', 'Y1', 'Y2']],
                               train_size=0.80)

XTrain = Train[['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']]
YTrain = Train[['Y0', 'Y1', 'Y2']]
XTest = Test[['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']]
YTest = Test[['Y0', 'Y1', 'Y2']]

scaler = StandardScaler().fit(XTrain)
XTrain = scaler.transform(XTrain)
XTest = scaler.transform(XTest)

mu, sigma = np.mean(YTrain), np.sqrt(np.var(YTrain))

# %% [markdown]
# Le réseau se compose des couches suivantes :
#
# - **5** couches cachées avec chacune **80** neurones.
# - Après chaque couche cachée, les données sont normalisées avec la couche **BatchNormalization**.
# - La couche de sortie possède **2** neurones (1 pour chaque output étudiée), où la fonction 'activation est celle décrite plus haut.
#
# <br>
# Il s'est avéré ne pas être utile de rajouter des couches de <b>Dropout</b> afin d'évite l'overfitting lors de l'entrainement. Ce dernier se fait sur 1000 époques.
# <br>
# La modélisation cherche donc une fonction $f$, qui n'est autre que le réseau de neurones tel que :<br><br>
# <center> $log(y_1,y_2, y_3) \sim f(x) \quad \forall x \in \mathbb{R}^6$ </center>

# %%
entry_1 = Input(shape=(XTrain.shape[1],))
li = Dense(80, activation=tf.nn.relu,
                         bias_initializer=initializers.RandomNormal(mean=mu[0],stddev=sigma[0]))(entry_1)
li = BatchNormalization()(li)
li = Dense(80, activation=tf.nn.relu,
                         bias_initializer=initializers.RandomNormal(mean=mu[0],stddev=sigma[0]))(li)
li = BatchNormalization()(li)
li = Dense(80, activation=tf.nn.relu,
                         bias_initializer=initializers.RandomNormal(mean=mu[0],stddev=sigma[0]))(li)
li = BatchNormalization()(li)
li = Dense(80, activation=tf.nn.relu,
                         bias_initializer=initializers.RandomNormal(mean=mu[0],stddev=sigma[0]))(li)
li = BatchNormalization()(li)
li = Dense(80, activation=tf.nn.relu,
                         bias_initializer=initializers.RandomNormal(mean=mu[0],stddev=sigma[0]))(li)
li = BatchNormalization()(li)
out_1 = Dense(3, activation=tf.nn.leaky_relu)(li)

model = keras.models.Model(entry_1, out_1)

model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mse'])


early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='mse',
            verbose=0,
            patience=1000,
            mode='max',
            restore_best_weights=True)

history = model.fit(np.asarray(XTrain).astype('float64'), np.asarray(YTrain).astype('float64'),
          epochs=1000, validation_data=(np.asarray(XTest).astype('float64'),
                                       np.asarray(YTest).astype('float64')), callbacks=[early_stopping],
                  verbose=1)
# Out:
# Epoch 1/1000
# 161/161 [==============================] - 1s 8ms/step - loss: 10.0048 - mse: 10.0048 - val_loss: 26.0451 - val_mse: 26.0451
# Epoch 2/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 3.2502 - mse: 3.2502 - val_loss: 1.2589 - val_mse: 1.2589
# Epoch 3/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.4086 - mse: 0.4086 - val_loss: 0.2886 - val_mse: 0.2886
# Epoch 4/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3719 - mse: 0.3719 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 5/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3475 - mse: 0.3475 - val_loss: 0.2302 - val_mse: 0.2302
# Epoch 6/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3187 - mse: 0.3187 - val_loss: 0.2410 - val_mse: 0.2410
# Epoch 7/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3421 - mse: 0.3421 - val_loss: 0.2225 - val_mse: 0.2225
# Epoch 8/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3491 - mse: 0.3491 - val_loss: 0.2088 - val_mse: 0.2088
# Epoch 9/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3091 - mse: 0.3091 - val_loss: 0.1863 - val_mse: 0.1863
# Epoch 10/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3263 - mse: 0.3263 - val_loss: 0.1974 - val_mse: 0.1974
# Epoch 11/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3270 - mse: 0.3270 - val_loss: 0.1880 - val_mse: 0.1880
# Epoch 12/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2989 - mse: 0.2989 - val_loss: 0.1953 - val_mse: 0.1953
# Epoch 13/1000
# 161/161 [==============================] - 2s 11ms/step - loss: 0.3036 - mse: 0.3036 - val_loss: 0.2041 - val_mse: 0.2041
# Epoch 14/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3151 - mse: 0.3151 - val_loss: 0.2094 - val_mse: 0.2094
# Epoch 15/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2991 - mse: 0.2991 - val_loss: 0.2072 - val_mse: 0.2072
# Epoch 16/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.3097 - mse: 0.3097 - val_loss: 0.1693 - val_mse: 0.1693
# Epoch 17/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.3032 - mse: 0.3032 - val_loss: 0.2247 - val_mse: 0.2247
# Epoch 18/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3180 - mse: 0.3180 - val_loss: 0.1747 - val_mse: 0.1747
# Epoch 19/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.3138 - mse: 0.3138 - val_loss: 0.2004 - val_mse: 0.2004
# Epoch 20/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2821 - mse: 0.2821 - val_loss: 0.1546 - val_mse: 0.1546
# Epoch 21/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2920 - mse: 0.2920 - val_loss: 0.1701 - val_mse: 0.1701
# Epoch 22/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3156 - mse: 0.3156 - val_loss: 0.2121 - val_mse: 0.2121
# Epoch 23/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2948 - mse: 0.2948 - val_loss: 0.1990 - val_mse: 0.1990
# Epoch 24/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2896 - mse: 0.2896 - val_loss: 0.2120 - val_mse: 0.2120
# Epoch 25/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2895 - mse: 0.2895 - val_loss: 0.2212 - val_mse: 0.2212
# Epoch 26/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2753 - mse: 0.2753 - val_loss: 0.1949 - val_mse: 0.1949
# Epoch 27/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2879 - mse: 0.2879 - val_loss: 0.1853 - val_mse: 0.1853
# Epoch 28/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2932 - mse: 0.2932 - val_loss: 0.2017 - val_mse: 0.2017
# Epoch 29/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2954 - mse: 0.2954 - val_loss: 0.1873 - val_mse: 0.1873
# Epoch 30/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2873 - mse: 0.2873 - val_loss: 0.1847 - val_mse: 0.1847
# Epoch 31/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2771 - mse: 0.2771 - val_loss: 0.1828 - val_mse: 0.1828
# Epoch 32/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2884 - mse: 0.2884 - val_loss: 0.1901 - val_mse: 0.1901
# Epoch 33/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2737 - mse: 0.2737 - val_loss: 0.2105 - val_mse: 0.2105
# Epoch 34/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2788 - mse: 0.2788 - val_loss: 0.1864 - val_mse: 0.1864
# Epoch 35/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2699 - mse: 0.2699 - val_loss: 0.2194 - val_mse: 0.2194
# Epoch 36/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.3004 - mse: 0.3004 - val_loss: 0.2142 - val_mse: 0.2142
# Epoch 37/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2788 - mse: 0.2788 - val_loss: 0.1848 - val_mse: 0.1848
# Epoch 38/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2805 - mse: 0.2805 - val_loss: 0.1804 - val_mse: 0.1804
# Epoch 39/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2872 - mse: 0.2872 - val_loss: 0.2655 - val_mse: 0.2655
# Epoch 40/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2797 - mse: 0.2797 - val_loss: 0.1705 - val_mse: 0.1705
# Epoch 41/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2760 - mse: 0.2760 - val_loss: 0.1908 - val_mse: 0.1908
# Epoch 42/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2591 - mse: 0.2591 - val_loss: 0.1700 - val_mse: 0.1700
# Epoch 43/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2705 - mse: 0.2705 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 44/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2655 - mse: 0.2655 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 45/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2858 - mse: 0.2858 - val_loss: 0.1904 - val_mse: 0.1904
# Epoch 46/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2806 - mse: 0.2806 - val_loss: 0.1982 - val_mse: 0.1982
# Epoch 47/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2685 - mse: 0.2685 - val_loss: 0.2192 - val_mse: 0.2192
# Epoch 48/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2783 - mse: 0.2783 - val_loss: 0.1849 - val_mse: 0.1849
# Epoch 49/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2638 - mse: 0.2638 - val_loss: 0.1698 - val_mse: 0.1698
# Epoch 50/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2874 - mse: 0.2874 - val_loss: 0.1653 - val_mse: 0.1653
# Epoch 51/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2819 - mse: 0.2819 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 52/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2665 - mse: 0.2665 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 53/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2593 - mse: 0.2593 - val_loss: 0.1652 - val_mse: 0.1652
# Epoch 54/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2567 - mse: 0.2567 - val_loss: 0.1720 - val_mse: 0.1720
# Epoch 55/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2775 - mse: 0.2775 - val_loss: 0.1897 - val_mse: 0.1897
# Epoch 56/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2551 - mse: 0.2551 - val_loss: 0.1691 - val_mse: 0.1691
# Epoch 57/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2708 - mse: 0.2708 - val_loss: 0.1819 - val_mse: 0.1819
# Epoch 58/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2674 - mse: 0.2674 - val_loss: 0.1830 - val_mse: 0.1830
# Epoch 59/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2522 - mse: 0.2522 - val_loss: 0.1702 - val_mse: 0.1702
# Epoch 60/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2662 - mse: 0.2662 - val_loss: 0.1825 - val_mse: 0.1825
# Epoch 61/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2617 - mse: 0.2617 - val_loss: 0.1637 - val_mse: 0.1637
# Epoch 62/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2726 - mse: 0.2726 - val_loss: 0.1654 - val_mse: 0.1654
# Epoch 63/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2729 - mse: 0.2729 - val_loss: 0.2089 - val_mse: 0.2089
# Epoch 64/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 0.1576 - val_mse: 0.1576
# Epoch 65/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2483 - mse: 0.2483 - val_loss: 0.1681 - val_mse: 0.1681
# Epoch 66/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2601 - mse: 0.2601 - val_loss: 0.1606 - val_mse: 0.1606
# Epoch 67/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2709 - mse: 0.2709 - val_loss: 0.1775 - val_mse: 0.1775
# Epoch 68/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2765 - mse: 0.2765 - val_loss: 0.1601 - val_mse: 0.1601
# Epoch 69/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2521 - mse: 0.2521 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 70/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2487 - mse: 0.2487 - val_loss: 0.1546 - val_mse: 0.1546
# Epoch 71/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2721 - mse: 0.2721 - val_loss: 0.1645 - val_mse: 0.1645
# Epoch 72/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2629 - mse: 0.2629 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 73/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2452 - mse: 0.2452 - val_loss: 0.1591 - val_mse: 0.1591
# Epoch 74/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2613 - mse: 0.2613 - val_loss: 0.1763 - val_mse: 0.1763
# Epoch 75/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2767 - mse: 0.2767 - val_loss: 0.1600 - val_mse: 0.1600
# Epoch 76/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2410 - mse: 0.2410 - val_loss: 0.1800 - val_mse: 0.1800
# Epoch 77/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2667 - mse: 0.2667 - val_loss: 0.2011 - val_mse: 0.2011
# Epoch 78/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2635 - mse: 0.2635 - val_loss: 0.1593 - val_mse: 0.1593
# Epoch 79/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2625 - mse: 0.2625 - val_loss: 0.1734 - val_mse: 0.1734
# Epoch 80/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2622 - mse: 0.2622 - val_loss: 0.1651 - val_mse: 0.1651
# Epoch 81/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2703 - mse: 0.2703 - val_loss: 0.1740 - val_mse: 0.1740
# Epoch 82/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2630 - mse: 0.2630 - val_loss: 0.1520 - val_mse: 0.1520
# Epoch 83/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2370 - mse: 0.2370 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 84/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2459 - mse: 0.2459 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 85/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2700 - mse: 0.2700 - val_loss: 0.1502 - val_mse: 0.1502
# Epoch 86/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2765 - mse: 0.2765 - val_loss: 0.2008 - val_mse: 0.2008
# Epoch 87/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 0.1618 - val_mse: 0.1618
# Epoch 88/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2565 - mse: 0.2565 - val_loss: 0.1804 - val_mse: 0.1804
# Epoch 89/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2422 - mse: 0.2422 - val_loss: 0.1698 - val_mse: 0.1698
# Epoch 90/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2559 - mse: 0.2559 - val_loss: 0.1565 - val_mse: 0.1565
# Epoch 91/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2505 - mse: 0.2505 - val_loss: 0.1479 - val_mse: 0.1479
# Epoch 92/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2577 - mse: 0.2577 - val_loss: 0.1479 - val_mse: 0.1479
# Epoch 93/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2397 - mse: 0.2397 - val_loss: 0.1538 - val_mse: 0.1538
# Epoch 94/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2421 - mse: 0.2421 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 95/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2556 - mse: 0.2556 - val_loss: 0.1549 - val_mse: 0.1549
# Epoch 96/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2599 - mse: 0.2599 - val_loss: 0.1578 - val_mse: 0.1578
# Epoch 97/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2520 - mse: 0.2520 - val_loss: 0.1615 - val_mse: 0.1615
# Epoch 98/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2438 - mse: 0.2438 - val_loss: 0.1642 - val_mse: 0.1642
# Epoch 99/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2558 - mse: 0.2558 - val_loss: 0.1663 - val_mse: 0.1663
# Epoch 100/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2611 - mse: 0.2611 - val_loss: 0.1654 - val_mse: 0.1654
# Epoch 101/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2381 - mse: 0.2381 - val_loss: 0.1560 - val_mse: 0.1560
# Epoch 102/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2501 - mse: 0.2501 - val_loss: 0.1537 - val_mse: 0.1537
# Epoch 103/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2423 - mse: 0.2423 - val_loss: 0.1771 - val_mse: 0.1771
# Epoch 104/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2529 - mse: 0.2529 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 105/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2432 - mse: 0.2432 - val_loss: 0.1483 - val_mse: 0.1483
# Epoch 106/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2473 - mse: 0.2473 - val_loss: 0.1516 - val_mse: 0.1516
# Epoch 107/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2453 - mse: 0.2453 - val_loss: 0.1600 - val_mse: 0.1600
# Epoch 108/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2447 - mse: 0.2447 - val_loss: 0.1527 - val_mse: 0.1527
# Epoch 109/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2586 - mse: 0.2586 - val_loss: 0.1618 - val_mse: 0.1618
# Epoch 110/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2302 - mse: 0.2302 - val_loss: 0.1534 - val_mse: 0.1534
# Epoch 111/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2368 - mse: 0.2368 - val_loss: 0.1576 - val_mse: 0.1576
# Epoch 112/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2651 - mse: 0.2651 - val_loss: 0.1643 - val_mse: 0.1643
# Epoch 113/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2346 - mse: 0.2346 - val_loss: 0.1551 - val_mse: 0.1551
# Epoch 114/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2591 - mse: 0.2591 - val_loss: 0.1544 - val_mse: 0.1544
# Epoch 115/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2512 - mse: 0.2512 - val_loss: 0.1428 - val_mse: 0.1428
# Epoch 116/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2358 - mse: 0.2358 - val_loss: 0.1697 - val_mse: 0.1697
# Epoch 117/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2371 - mse: 0.2371 - val_loss: 0.1714 - val_mse: 0.1714
# Epoch 118/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.1614 - val_mse: 0.1614
# Epoch 119/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2408 - mse: 0.2408 - val_loss: 0.1757 - val_mse: 0.1757
# Epoch 120/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2375 - mse: 0.2375 - val_loss: 0.1581 - val_mse: 0.1581
# Epoch 121/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2478 - mse: 0.2478 - val_loss: 0.1631 - val_mse: 0.1631
# Epoch 122/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2707 - mse: 0.2707 - val_loss: 0.1583 - val_mse: 0.1583
# Epoch 123/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2396 - mse: 0.2396 - val_loss: 0.1451 - val_mse: 0.1451
# Epoch 124/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2587 - mse: 0.2587 - val_loss: 0.1524 - val_mse: 0.1524
# Epoch 125/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2387 - mse: 0.2387 - val_loss: 0.1507 - val_mse: 0.1507
# Epoch 126/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.1495 - val_mse: 0.1495
# Epoch 127/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 0.1507 - val_mse: 0.1507
# Epoch 128/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2284 - mse: 0.2284 - val_loss: 0.1449 - val_mse: 0.1449
# Epoch 129/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2446 - mse: 0.2446 - val_loss: 0.1566 - val_mse: 0.1566
# Epoch 130/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2409 - mse: 0.2409 - val_loss: 0.1578 - val_mse: 0.1578
# Epoch 131/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2330 - mse: 0.2330 - val_loss: 0.1651 - val_mse: 0.1651
# Epoch 132/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2298 - mse: 0.2298 - val_loss: 0.1587 - val_mse: 0.1587
# Epoch 133/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2405 - mse: 0.2405 - val_loss: 0.1550 - val_mse: 0.1550
# Epoch 134/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2525 - mse: 0.2525 - val_loss: 0.1826 - val_mse: 0.1826
# Epoch 135/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2453 - mse: 0.2453 - val_loss: 0.1506 - val_mse: 0.1506
# Epoch 136/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2322 - mse: 0.2322 - val_loss: 0.1593 - val_mse: 0.1593
# Epoch 137/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2340 - mse: 0.2340 - val_loss: 0.1468 - val_mse: 0.1468
# Epoch 138/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2456 - mse: 0.2456 - val_loss: 0.1513 - val_mse: 0.1513
# Epoch 139/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2463 - mse: 0.2463 - val_loss: 0.1642 - val_mse: 0.1642
# Epoch 140/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2352 - mse: 0.2352 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 141/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2329 - mse: 0.2329 - val_loss: 0.1497 - val_mse: 0.1497
# Epoch 142/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2449 - mse: 0.2449 - val_loss: 0.1548 - val_mse: 0.1548
# Epoch 143/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2259 - mse: 0.2259 - val_loss: 0.1505 - val_mse: 0.1505
# Epoch 144/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2417 - mse: 0.2417 - val_loss: 0.1657 - val_mse: 0.1657
# Epoch 145/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2464 - mse: 0.2464 - val_loss: 0.1429 - val_mse: 0.1429
# Epoch 146/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2490 - mse: 0.2490 - val_loss: 0.1650 - val_mse: 0.1650
# Epoch 147/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2316 - mse: 0.2316 - val_loss: 0.1493 - val_mse: 0.1493
# Epoch 148/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2278 - mse: 0.2278 - val_loss: 0.1683 - val_mse: 0.1683
# Epoch 149/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2413 - mse: 0.2413 - val_loss: 0.1724 - val_mse: 0.1724
# Epoch 150/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2314 - mse: 0.2314 - val_loss: 0.1546 - val_mse: 0.1546
# Epoch 151/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2534 - mse: 0.2534 - val_loss: 0.1587 - val_mse: 0.1587
# Epoch 152/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2259 - mse: 0.2259 - val_loss: 0.1523 - val_mse: 0.1523
# Epoch 153/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2314 - mse: 0.2314 - val_loss: 0.1704 - val_mse: 0.1704
# Epoch 154/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2413 - mse: 0.2413 - val_loss: 0.1476 - val_mse: 0.1476
# Epoch 155/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2467 - mse: 0.2467 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 156/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2391 - mse: 0.2391 - val_loss: 0.1491 - val_mse: 0.1491
# Epoch 157/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2417 - mse: 0.2417 - val_loss: 0.1481 - val_mse: 0.1481
# Epoch 158/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2315 - mse: 0.2315 - val_loss: 0.1550 - val_mse: 0.1550
# Epoch 159/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2425 - mse: 0.2425 - val_loss: 0.1587 - val_mse: 0.1587
# Epoch 160/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2371 - mse: 0.2371 - val_loss: 0.1591 - val_mse: 0.1591
# Epoch 161/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2447 - mse: 0.2447 - val_loss: 0.1452 - val_mse: 0.1452
# Epoch 162/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2281 - mse: 0.2281 - val_loss: 0.1467 - val_mse: 0.1467
# Epoch 163/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2409 - mse: 0.2409 - val_loss: 0.1565 - val_mse: 0.1565
# Epoch 164/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2437 - mse: 0.2437 - val_loss: 0.1557 - val_mse: 0.1557
# Epoch 165/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2413 - mse: 0.2413 - val_loss: 0.1563 - val_mse: 0.1563
# Epoch 166/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2444 - mse: 0.2444 - val_loss: 0.1429 - val_mse: 0.1429
# Epoch 167/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2294 - mse: 0.2294 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 168/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2376 - mse: 0.2376 - val_loss: 0.1591 - val_mse: 0.1591
# Epoch 169/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2338 - mse: 0.2338 - val_loss: 0.1539 - val_mse: 0.1539
# Epoch 170/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2421 - mse: 0.2421 - val_loss: 0.1629 - val_mse: 0.1629
# Epoch 171/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2184 - mse: 0.2184 - val_loss: 0.1626 - val_mse: 0.1626
# Epoch 172/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2318 - mse: 0.2318 - val_loss: 0.1567 - val_mse: 0.1567
# Epoch 173/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2305 - mse: 0.2305 - val_loss: 0.1437 - val_mse: 0.1437
# Epoch 174/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2438 - mse: 0.2438 - val_loss: 0.1528 - val_mse: 0.1528
# Epoch 175/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2491 - mse: 0.2491 - val_loss: 0.1484 - val_mse: 0.1484
# Epoch 176/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2414 - mse: 0.2414 - val_loss: 0.1389 - val_mse: 0.1389
# Epoch 177/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2300 - mse: 0.2300 - val_loss: 0.1532 - val_mse: 0.1532
# Epoch 178/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2319 - mse: 0.2319 - val_loss: 0.1444 - val_mse: 0.1444
# Epoch 179/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2456 - mse: 0.2456 - val_loss: 0.1678 - val_mse: 0.1678
# Epoch 180/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2215 - mse: 0.2215 - val_loss: 0.1461 - val_mse: 0.1461
# Epoch 181/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2353 - mse: 0.2353 - val_loss: 0.1736 - val_mse: 0.1736
# Epoch 182/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2365 - mse: 0.2365 - val_loss: 0.1595 - val_mse: 0.1595
# Epoch 183/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2293 - mse: 0.2293 - val_loss: 0.1599 - val_mse: 0.1599
# Epoch 184/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2313 - mse: 0.2313 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 185/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2402 - mse: 0.2402 - val_loss: 0.1684 - val_mse: 0.1684
# Epoch 186/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2356 - mse: 0.2356 - val_loss: 0.1409 - val_mse: 0.1409
# Epoch 187/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2507 - mse: 0.2507 - val_loss: 0.1621 - val_mse: 0.1621
# Epoch 188/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2300 - mse: 0.2300 - val_loss: 0.1596 - val_mse: 0.1596
# Epoch 189/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2419 - mse: 0.2419 - val_loss: 0.1552 - val_mse: 0.1552
# Epoch 190/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2270 - mse: 0.2270 - val_loss: 0.1486 - val_mse: 0.1486
# Epoch 191/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2399 - mse: 0.2399 - val_loss: 0.1547 - val_mse: 0.1547
# Epoch 192/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.1629 - val_mse: 0.1629
# Epoch 193/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2421 - mse: 0.2421 - val_loss: 0.1444 - val_mse: 0.1444
# Epoch 194/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2453 - mse: 0.2453 - val_loss: 0.1651 - val_mse: 0.1651
# Epoch 195/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2272 - mse: 0.2272 - val_loss: 0.1450 - val_mse: 0.1450
# Epoch 196/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2399 - mse: 0.2399 - val_loss: 0.1439 - val_mse: 0.1439
# Epoch 197/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2368 - mse: 0.2368 - val_loss: 0.1399 - val_mse: 0.1399
# Epoch 198/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2392 - mse: 0.2392 - val_loss: 0.1543 - val_mse: 0.1543
# Epoch 199/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2323 - mse: 0.2323 - val_loss: 0.1531 - val_mse: 0.1531
# Epoch 200/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2201 - mse: 0.2201 - val_loss: 0.1434 - val_mse: 0.1434
# Epoch 201/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.1625 - val_mse: 0.1625
# Epoch 202/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2246 - mse: 0.2246 - val_loss: 0.1493 - val_mse: 0.1493
# Epoch 203/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2355 - mse: 0.2355 - val_loss: 0.1639 - val_mse: 0.1639
# Epoch 204/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2293 - mse: 0.2293 - val_loss: 0.1473 - val_mse: 0.1473
# Epoch 205/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2296 - mse: 0.2296 - val_loss: 0.1617 - val_mse: 0.1617
# Epoch 206/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2388 - mse: 0.2388 - val_loss: 0.1491 - val_mse: 0.1491
# Epoch 207/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2307 - mse: 0.2307 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 208/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2252 - mse: 0.2252 - val_loss: 0.1481 - val_mse: 0.1481
# Epoch 209/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2236 - mse: 0.2236 - val_loss: 0.1571 - val_mse: 0.1571
# Epoch 210/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2325 - mse: 0.2325 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 211/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 212/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2261 - mse: 0.2261 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 213/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2252 - mse: 0.2252 - val_loss: 0.1517 - val_mse: 0.1517
# Epoch 214/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2388 - mse: 0.2388 - val_loss: 0.1448 - val_mse: 0.1448
# Epoch 215/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2237 - mse: 0.2237 - val_loss: 0.1508 - val_mse: 0.1508
# Epoch 216/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.1445 - val_mse: 0.1445
# Epoch 217/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2162 - mse: 0.2162 - val_loss: 0.1526 - val_mse: 0.1526
# Epoch 218/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2421 - mse: 0.2421 - val_loss: 0.1543 - val_mse: 0.1543
# Epoch 219/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.1557 - val_mse: 0.1557
# Epoch 220/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2353 - mse: 0.2353 - val_loss: 0.1539 - val_mse: 0.1539
# Epoch 221/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2428 - mse: 0.2428 - val_loss: 0.1449 - val_mse: 0.1449
# Epoch 222/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2381 - mse: 0.2381 - val_loss: 0.1461 - val_mse: 0.1461
# Epoch 223/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2417 - mse: 0.2417 - val_loss: 0.1440 - val_mse: 0.1440
# Epoch 224/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2491 - mse: 0.2491 - val_loss: 0.1550 - val_mse: 0.1550
# Epoch 225/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2153 - mse: 0.2153 - val_loss: 0.1641 - val_mse: 0.1641
# Epoch 226/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2391 - mse: 0.2391 - val_loss: 0.1544 - val_mse: 0.1544
# Epoch 227/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2361 - mse: 0.2361 - val_loss: 0.1446 - val_mse: 0.1446
# Epoch 228/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2349 - mse: 0.2349 - val_loss: 0.1478 - val_mse: 0.1478
# Epoch 229/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2332 - mse: 0.2332 - val_loss: 0.1589 - val_mse: 0.1589
# Epoch 230/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2364 - mse: 0.2364 - val_loss: 0.1529 - val_mse: 0.1529
# Epoch 231/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2385 - mse: 0.2385 - val_loss: 0.1492 - val_mse: 0.1492
# Epoch 232/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2385 - mse: 0.2385 - val_loss: 0.1466 - val_mse: 0.1466
# Epoch 233/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2342 - mse: 0.2342 - val_loss: 0.1506 - val_mse: 0.1506
# Epoch 234/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2557 - mse: 0.2557 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 235/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2182 - mse: 0.2182 - val_loss: 0.1473 - val_mse: 0.1473
# Epoch 236/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.1421 - val_mse: 0.1421
# Epoch 237/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2427 - mse: 0.2427 - val_loss: 0.1480 - val_mse: 0.1480
# Epoch 238/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2309 - mse: 0.2309 - val_loss: 0.1480 - val_mse: 0.1480
# Epoch 239/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2358 - mse: 0.2358 - val_loss: 0.1515 - val_mse: 0.1515
# Epoch 240/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2505 - mse: 0.2505 - val_loss: 0.1534 - val_mse: 0.1534
# Epoch 241/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2396 - mse: 0.2396 - val_loss: 0.1633 - val_mse: 0.1633
# Epoch 242/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2296 - mse: 0.2296 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 243/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2137 - mse: 0.2137 - val_loss: 0.1673 - val_mse: 0.1673
# Epoch 244/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2342 - mse: 0.2342 - val_loss: 0.1449 - val_mse: 0.1449
# Epoch 245/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2454 - mse: 0.2454 - val_loss: 0.1448 - val_mse: 0.1448
# Epoch 246/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2258 - mse: 0.2258 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 247/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2342 - mse: 0.2342 - val_loss: 0.1446 - val_mse: 0.1446
# Epoch 248/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2327 - mse: 0.2327 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 249/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2162 - mse: 0.2162 - val_loss: 0.1537 - val_mse: 0.1537
# Epoch 250/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2188 - mse: 0.2188 - val_loss: 0.1590 - val_mse: 0.1590
# Epoch 251/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.1488 - val_mse: 0.1488
# Epoch 252/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2293 - mse: 0.2293 - val_loss: 0.1444 - val_mse: 0.1444
# Epoch 253/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2430 - mse: 0.2430 - val_loss: 0.1465 - val_mse: 0.1465
# Epoch 254/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2244 - mse: 0.2244 - val_loss: 0.1406 - val_mse: 0.1406
# Epoch 255/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2330 - mse: 0.2330 - val_loss: 0.1607 - val_mse: 0.1607
# Epoch 256/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2273 - mse: 0.2273 - val_loss: 0.1541 - val_mse: 0.1541
# Epoch 257/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2326 - mse: 0.2326 - val_loss: 0.1478 - val_mse: 0.1478
# Epoch 258/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2404 - mse: 0.2404 - val_loss: 0.1634 - val_mse: 0.1634
# Epoch 259/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.1552 - val_mse: 0.1552
# Epoch 260/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.1405 - val_mse: 0.1405
# Epoch 261/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2205 - mse: 0.2205 - val_loss: 0.1561 - val_mse: 0.1561
# Epoch 262/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2430 - mse: 0.2430 - val_loss: 0.1564 - val_mse: 0.1564
# Epoch 263/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2139 - mse: 0.2139 - val_loss: 0.1489 - val_mse: 0.1489
# Epoch 264/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2270 - mse: 0.2270 - val_loss: 0.1458 - val_mse: 0.1458
# Epoch 265/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2273 - mse: 0.2273 - val_loss: 0.1523 - val_mse: 0.1523
# Epoch 266/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 267/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2353 - mse: 0.2353 - val_loss: 0.1515 - val_mse: 0.1515
# Epoch 268/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.1525 - val_mse: 0.1525
# Epoch 269/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2293 - mse: 0.2293 - val_loss: 0.1497 - val_mse: 0.1497
# Epoch 270/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2218 - mse: 0.2218 - val_loss: 0.1576 - val_mse: 0.1576
# Epoch 271/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2418 - mse: 0.2418 - val_loss: 0.1420 - val_mse: 0.1420
# Epoch 272/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.1399 - val_mse: 0.1399
# Epoch 273/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2367 - mse: 0.2367 - val_loss: 0.1486 - val_mse: 0.1486
# Epoch 274/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2327 - mse: 0.2327 - val_loss: 0.1466 - val_mse: 0.1466
# Epoch 275/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2364 - mse: 0.2364 - val_loss: 0.1462 - val_mse: 0.1462
# Epoch 276/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2206 - mse: 0.2206 - val_loss: 0.1517 - val_mse: 0.1517
# Epoch 277/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.1498 - val_mse: 0.1498
# Epoch 278/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.1594 - val_mse: 0.1594
# Epoch 279/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2288 - mse: 0.2288 - val_loss: 0.1522 - val_mse: 0.1522
# Epoch 280/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.1554 - val_mse: 0.1554
# Epoch 281/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2292 - mse: 0.2292 - val_loss: 0.1666 - val_mse: 0.1666
# Epoch 282/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2176 - mse: 0.2176 - val_loss: 0.1467 - val_mse: 0.1467
# Epoch 283/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.1484 - val_mse: 0.1484
# Epoch 284/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2179 - mse: 0.2179 - val_loss: 0.1566 - val_mse: 0.1566
# Epoch 285/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2305 - mse: 0.2305 - val_loss: 0.1521 - val_mse: 0.1521
# Epoch 286/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2218 - mse: 0.2218 - val_loss: 0.1627 - val_mse: 0.1627
# Epoch 287/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2397 - mse: 0.2397 - val_loss: 0.1554 - val_mse: 0.1554
# Epoch 288/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2120 - mse: 0.2120 - val_loss: 0.1367 - val_mse: 0.1367
# Epoch 289/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2349 - mse: 0.2349 - val_loss: 0.1452 - val_mse: 0.1452
# Epoch 290/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2102 - mse: 0.2102 - val_loss: 0.1468 - val_mse: 0.1468
# Epoch 291/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.1471 - val_mse: 0.1471
# Epoch 292/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2401 - mse: 0.2401 - val_loss: 0.1608 - val_mse: 0.1608
# Epoch 293/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2328 - mse: 0.2328 - val_loss: 0.1526 - val_mse: 0.1526
# Epoch 294/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2383 - mse: 0.2383 - val_loss: 0.1518 - val_mse: 0.1518
# Epoch 295/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2300 - mse: 0.2300 - val_loss: 0.1472 - val_mse: 0.1472
# Epoch 296/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2317 - mse: 0.2317 - val_loss: 0.1515 - val_mse: 0.1515
# Epoch 297/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.1432 - val_mse: 0.1432
# Epoch 298/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2219 - mse: 0.2219 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 299/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.1430 - val_mse: 0.1430
# Epoch 300/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2331 - mse: 0.2331 - val_loss: 0.1456 - val_mse: 0.1456
# Epoch 301/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2235 - mse: 0.2235 - val_loss: 0.1492 - val_mse: 0.1492
# Epoch 302/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2266 - mse: 0.2266 - val_loss: 0.1537 - val_mse: 0.1537
# Epoch 303/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2157 - mse: 0.2157 - val_loss: 0.1409 - val_mse: 0.1409
# Epoch 304/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2318 - mse: 0.2318 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 305/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2196 - mse: 0.2196 - val_loss: 0.1434 - val_mse: 0.1434
# Epoch 306/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2304 - mse: 0.2304 - val_loss: 0.2135 - val_mse: 0.2135
# Epoch 307/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2358 - mse: 0.2358 - val_loss: 0.1504 - val_mse: 0.1504
# Epoch 308/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2284 - mse: 0.2284 - val_loss: 0.1525 - val_mse: 0.1525
# Epoch 309/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2310 - mse: 0.2310 - val_loss: 0.1490 - val_mse: 0.1490
# Epoch 310/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2286 - mse: 0.2286 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 311/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2550 - mse: 0.2550 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 312/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2308 - mse: 0.2308 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 313/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2131 - mse: 0.2131 - val_loss: 0.1409 - val_mse: 0.1409
# Epoch 314/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2322 - mse: 0.2322 - val_loss: 0.1569 - val_mse: 0.1569
# Epoch 315/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2146 - mse: 0.2146 - val_loss: 0.1473 - val_mse: 0.1473
# Epoch 316/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.1502 - val_mse: 0.1502
# Epoch 317/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2214 - mse: 0.2214 - val_loss: 0.1669 - val_mse: 0.1669
# Epoch 318/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.1560 - val_mse: 0.1560
# Epoch 319/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2216 - mse: 0.2216 - val_loss: 0.1456 - val_mse: 0.1456
# Epoch 320/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2370 - mse: 0.2370 - val_loss: 0.1477 - val_mse: 0.1477
# Epoch 321/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2313 - mse: 0.2313 - val_loss: 0.1712 - val_mse: 0.1712
# Epoch 322/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2212 - mse: 0.2212 - val_loss: 0.1568 - val_mse: 0.1568
# Epoch 323/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2168 - mse: 0.2168 - val_loss: 0.1401 - val_mse: 0.1401
# Epoch 324/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2288 - mse: 0.2288 - val_loss: 0.1417 - val_mse: 0.1417
# Epoch 325/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2244 - mse: 0.2244 - val_loss: 0.1395 - val_mse: 0.1395
# Epoch 326/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2330 - mse: 0.2330 - val_loss: 0.1485 - val_mse: 0.1485
# Epoch 327/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2308 - mse: 0.2308 - val_loss: 0.1494 - val_mse: 0.1494
# Epoch 328/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2292 - mse: 0.2292 - val_loss: 0.1401 - val_mse: 0.1401
# Epoch 329/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2377 - mse: 0.2377 - val_loss: 0.1502 - val_mse: 0.1502
# Epoch 330/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.1435 - val_mse: 0.1435
# Epoch 331/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2274 - mse: 0.2274 - val_loss: 0.1476 - val_mse: 0.1476
# Epoch 332/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2137 - mse: 0.2137 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 333/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.1508 - val_mse: 0.1508
# Epoch 334/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2271 - mse: 0.2271 - val_loss: 0.1388 - val_mse: 0.1388
# Epoch 335/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2242 - mse: 0.2242 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 336/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2339 - mse: 0.2339 - val_loss: 0.1479 - val_mse: 0.1479
# Epoch 337/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2189 - mse: 0.2189 - val_loss: 0.1482 - val_mse: 0.1482
# Epoch 338/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2278 - mse: 0.2278 - val_loss: 0.1717 - val_mse: 0.1717
# Epoch 339/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.1487 - val_mse: 0.1487
# Epoch 340/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2269 - mse: 0.2269 - val_loss: 0.1520 - val_mse: 0.1520
# Epoch 341/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2173 - mse: 0.2173 - val_loss: 0.1406 - val_mse: 0.1406
# Epoch 342/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2282 - mse: 0.2282 - val_loss: 0.1442 - val_mse: 0.1442
# Epoch 343/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2216 - mse: 0.2216 - val_loss: 0.1494 - val_mse: 0.1494
# Epoch 344/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2236 - mse: 0.2236 - val_loss: 0.1394 - val_mse: 0.1394
# Epoch 345/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2270 - mse: 0.2270 - val_loss: 0.1445 - val_mse: 0.1445
# Epoch 346/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2209 - mse: 0.2209 - val_loss: 0.1448 - val_mse: 0.1448
# Epoch 347/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2575 - mse: 0.2575 - val_loss: 0.1549 - val_mse: 0.1549
# Epoch 348/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2355 - mse: 0.2355 - val_loss: 0.1446 - val_mse: 0.1446
# Epoch 349/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.1489 - val_mse: 0.1489
# Epoch 350/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2246 - mse: 0.2246 - val_loss: 0.1531 - val_mse: 0.1531
# Epoch 351/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2338 - mse: 0.2338 - val_loss: 0.1627 - val_mse: 0.1627
# Epoch 352/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.1547 - val_mse: 0.1547
# Epoch 353/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2201 - mse: 0.2201 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 354/1000
# ...
# Epoch 884/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2007 - mse: 0.2007 - val_loss: 0.1363 - val_mse: 0.1363
# Epoch 885/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2110 - mse: 0.2110 - val_loss: 0.1386 - val_mse: 0.1386
# Epoch 886/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1900 - mse: 0.1900 - val_loss: 0.1396 - val_mse: 0.1396
# Epoch 887/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2007 - mse: 0.2007 - val_loss: 0.1384 - val_mse: 0.1384
# Epoch 888/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2159 - mse: 0.2159 - val_loss: 0.1341 - val_mse: 0.1341
# Epoch 889/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2133 - mse: 0.2133 - val_loss: 0.1378 - val_mse: 0.1378
# Epoch 890/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2006 - mse: 0.2006 - val_loss: 0.1372 - val_mse: 0.1372
# Epoch 891/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2026 - mse: 0.2026 - val_loss: 0.1353 - val_mse: 0.1353
# Epoch 892/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2218 - mse: 0.2218 - val_loss: 0.1526 - val_mse: 0.1526
# Epoch 893/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1932 - mse: 0.1932 - val_loss: 0.1350 - val_mse: 0.1350
# Epoch 894/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2094 - mse: 0.2094 - val_loss: 0.1388 - val_mse: 0.1388
# Epoch 895/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2119 - mse: 0.2119 - val_loss: 0.1511 - val_mse: 0.1511
# Epoch 896/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2037 - mse: 0.2037 - val_loss: 0.1453 - val_mse: 0.1453
# Epoch 897/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2036 - mse: 0.2036 - val_loss: 0.1384 - val_mse: 0.1384
# Epoch 898/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2041 - mse: 0.2041 - val_loss: 0.1495 - val_mse: 0.1495
# Epoch 899/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1983 - mse: 0.1983 - val_loss: 0.1442 - val_mse: 0.1442
# Epoch 900/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2004 - mse: 0.2004 - val_loss: 0.1392 - val_mse: 0.1392
# Epoch 901/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2036 - mse: 0.2036 - val_loss: 0.1385 - val_mse: 0.1385
# Epoch 902/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2175 - mse: 0.2175 - val_loss: 0.1366 - val_mse: 0.1366
# Epoch 903/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1909 - mse: 0.1909 - val_loss: 0.1358 - val_mse: 0.1358
# Epoch 904/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2041 - mse: 0.2041 - val_loss: 0.1376 - val_mse: 0.1376
# Epoch 905/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2141 - mse: 0.2141 - val_loss: 0.1393 - val_mse: 0.1393
# Epoch 906/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2085 - mse: 0.2085 - val_loss: 0.1468 - val_mse: 0.1468
# Epoch 907/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2052 - mse: 0.2052 - val_loss: 0.1371 - val_mse: 0.1371
# Epoch 908/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2046 - mse: 0.2046 - val_loss: 0.1416 - val_mse: 0.1416
# Epoch 909/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2131 - mse: 0.2131 - val_loss: 0.1475 - val_mse: 0.1475
# Epoch 910/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1984 - mse: 0.1984 - val_loss: 0.1438 - val_mse: 0.1438
# Epoch 911/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2185 - mse: 0.2185 - val_loss: 0.1375 - val_mse: 0.1375
# Epoch 912/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2178 - mse: 0.2178 - val_loss: 0.1441 - val_mse: 0.1441
# Epoch 913/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2021 - mse: 0.2021 - val_loss: 0.1388 - val_mse: 0.1388
# Epoch 914/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2156 - mse: 0.2156 - val_loss: 0.1425 - val_mse: 0.1425
# Epoch 915/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1866 - mse: 0.1866 - val_loss: 0.1358 - val_mse: 0.1358
# Epoch 916/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1997 - mse: 0.1997 - val_loss: 0.1389 - val_mse: 0.1389
# Epoch 917/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2019 - mse: 0.2019 - val_loss: 0.1337 - val_mse: 0.1337
# Epoch 918/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2076 - mse: 0.2076 - val_loss: 0.1388 - val_mse: 0.1388
# Epoch 919/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2080 - mse: 0.2080 - val_loss: 0.1423 - val_mse: 0.1423
# Epoch 920/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2050 - mse: 0.2050 - val_loss: 0.1446 - val_mse: 0.1446
# Epoch 921/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1994 - mse: 0.1994 - val_loss: 0.1434 - val_mse: 0.1434
# Epoch 922/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2111 - mse: 0.2111 - val_loss: 0.1458 - val_mse: 0.1458
# Epoch 923/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2062 - mse: 0.2062 - val_loss: 0.1365 - val_mse: 0.1365
# Epoch 924/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1968 - mse: 0.1968 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 925/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2198 - mse: 0.2198 - val_loss: 0.1460 - val_mse: 0.1460
# Epoch 926/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2022 - mse: 0.2022 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 927/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1987 - mse: 0.1987 - val_loss: 0.1430 - val_mse: 0.1430
# Epoch 928/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1996 - mse: 0.1996 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 929/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2104 - mse: 0.2104 - val_loss: 0.1411 - val_mse: 0.1411
# Epoch 930/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2139 - mse: 0.2139 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 931/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2032 - mse: 0.2032 - val_loss: 0.1347 - val_mse: 0.1347
# Epoch 932/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1993 - mse: 0.1993 - val_loss: 0.1425 - val_mse: 0.1425
# Epoch 933/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1999 - mse: 0.1999 - val_loss: 0.1436 - val_mse: 0.1436
# Epoch 934/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2017 - mse: 0.2017 - val_loss: 0.1382 - val_mse: 0.1382
# Epoch 935/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1948 - mse: 0.1948 - val_loss: 0.1377 - val_mse: 0.1377
# Epoch 936/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2035 - mse: 0.2035 - val_loss: 0.1485 - val_mse: 0.1485
# Epoch 937/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2003 - mse: 0.2003 - val_loss: 0.1315 - val_mse: 0.1315
# Epoch 938/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2000 - mse: 0.2000 - val_loss: 0.1368 - val_mse: 0.1368
# Epoch 939/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2076 - mse: 0.2076 - val_loss: 0.1390 - val_mse: 0.1390
# Epoch 940/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2042 - mse: 0.2042 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 941/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2089 - mse: 0.2089 - val_loss: 0.1487 - val_mse: 0.1487
# Epoch 942/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.1341 - val_mse: 0.1341
# Epoch 943/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2037 - mse: 0.2037 - val_loss: 0.1429 - val_mse: 0.1429
# Epoch 944/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1967 - mse: 0.1967 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 945/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1991 - mse: 0.1991 - val_loss: 0.1406 - val_mse: 0.1406
# Epoch 946/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2015 - mse: 0.2015 - val_loss: 0.1464 - val_mse: 0.1464
# Epoch 947/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1450 - val_mse: 0.1450
# Epoch 948/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2074 - mse: 0.2074 - val_loss: 0.1413 - val_mse: 0.1413
# Epoch 949/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1956 - mse: 0.1956 - val_loss: 0.1445 - val_mse: 0.1445
# Epoch 950/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1979 - mse: 0.1979 - val_loss: 0.1357 - val_mse: 0.1357
# Epoch 951/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.1438 - val_mse: 0.1438
# Epoch 952/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.1861 - mse: 0.1861 - val_loss: 0.1350 - val_mse: 0.1350
# Epoch 953/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2065 - mse: 0.2065 - val_loss: 0.1334 - val_mse: 0.1334
# Epoch 954/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2156 - mse: 0.2156 - val_loss: 0.1389 - val_mse: 0.1389
# Epoch 955/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2083 - mse: 0.2083 - val_loss: 0.1335 - val_mse: 0.1335
# Epoch 956/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2052 - mse: 0.2052 - val_loss: 0.1351 - val_mse: 0.1351
# Epoch 957/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1968 - mse: 0.1968 - val_loss: 0.1418 - val_mse: 0.1418
# Epoch 958/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1464 - val_mse: 0.1464
# Epoch 959/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.1987 - mse: 0.1987 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 960/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1876 - mse: 0.1876 - val_loss: 0.1395 - val_mse: 0.1395
# Epoch 961/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2015 - mse: 0.2015 - val_loss: 0.1365 - val_mse: 0.1365
# Epoch 962/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2087 - mse: 0.2087 - val_loss: 0.1409 - val_mse: 0.1409
# Epoch 963/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2031 - mse: 0.2031 - val_loss: 0.1485 - val_mse: 0.1485
# Epoch 964/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2090 - mse: 0.2090 - val_loss: 0.1316 - val_mse: 0.1316
# Epoch 965/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1870 - mse: 0.1870 - val_loss: 0.1332 - val_mse: 0.1332
# Epoch 966/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2021 - mse: 0.2021 - val_loss: 0.1331 - val_mse: 0.1331
# Epoch 967/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2099 - mse: 0.2099 - val_loss: 0.1368 - val_mse: 0.1368
# Epoch 968/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2153 - mse: 0.2153 - val_loss: 0.1402 - val_mse: 0.1402
# Epoch 969/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2062 - mse: 0.2062 - val_loss: 0.1462 - val_mse: 0.1462
# Epoch 970/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2123 - mse: 0.2123 - val_loss: 0.1420 - val_mse: 0.1420
# Epoch 971/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2057 - mse: 0.2057 - val_loss: 0.1407 - val_mse: 0.1407
# Epoch 972/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2059 - mse: 0.2059 - val_loss: 0.1423 - val_mse: 0.1423
# Epoch 973/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2010 - mse: 0.2010 - val_loss: 0.1393 - val_mse: 0.1393
# Epoch 974/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1916 - mse: 0.1916 - val_loss: 0.1423 - val_mse: 0.1423
# Epoch 975/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2068 - mse: 0.2068 - val_loss: 0.1444 - val_mse: 0.1444
# Epoch 976/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2030 - mse: 0.2030 - val_loss: 0.1456 - val_mse: 0.1456
# Epoch 977/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2168 - mse: 0.2168 - val_loss: 0.1333 - val_mse: 0.1333
# Epoch 978/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1940 - mse: 0.1940 - val_loss: 0.1368 - val_mse: 0.1368
# Epoch 979/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1994 - mse: 0.1994 - val_loss: 0.1403 - val_mse: 0.1403
# Epoch 980/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2011 - mse: 0.2011 - val_loss: 0.1378 - val_mse: 0.1378
# Epoch 981/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2070 - mse: 0.2070 - val_loss: 0.1370 - val_mse: 0.1370
# Epoch 982/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2010 - mse: 0.2010 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 983/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1462 - val_mse: 0.1462
# Epoch 984/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2016 - mse: 0.2016 - val_loss: 0.1359 - val_mse: 0.1359
# Epoch 985/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.1959 - mse: 0.1959 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 986/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1994 - mse: 0.1994 - val_loss: 0.1376 - val_mse: 0.1376
# Epoch 987/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2060 - mse: 0.2060 - val_loss: 0.1390 - val_mse: 0.1390
# Epoch 988/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.1918 - mse: 0.1918 - val_loss: 0.1384 - val_mse: 0.1384
# Epoch 989/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2014 - mse: 0.2014 - val_loss: 0.1370 - val_mse: 0.1370
# Epoch 990/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1913 - mse: 0.1913 - val_loss: 0.1461 - val_mse: 0.1461
# Epoch 991/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2162 - mse: 0.2162 - val_loss: 0.1376 - val_mse: 0.1376
# Epoch 992/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1989 - mse: 0.1989 - val_loss: 0.1422 - val_mse: 0.1422
# Epoch 993/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2148 - mse: 0.2148 - val_loss: 0.1346 - val_mse: 0.1346
# Epoch 994/1000
# 161/161 [==============================] - 1s 6ms/step - loss: 0.1955 - mse: 0.1955 - val_loss: 0.1383 - val_mse: 0.1383
# Epoch 995/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2041 - mse: 0.2041 - val_loss: 0.1413 - val_mse: 0.1413
# Epoch 996/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1335 - val_mse: 0.1335
# Epoch 997/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1933 - mse: 0.1933 - val_loss: 0.1406 - val_mse: 0.1406
# Epoch 998/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2133 - mse: 0.2133 - val_loss: 0.1366 - val_mse: 0.1366
# Epoch 999/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.2059 - mse: 0.2059 - val_loss: 0.1325 - val_mse: 0.1325
# Epoch 1000/1000
# 161/161 [==============================] - 1s 7ms/step - loss: 0.1996 - mse: 0.1996 - val_loss: 0.1403 - val_mse: 0.1403

# %% [markdown]
# #### Validation du modèle entrainé

# %% [markdown]
# Le coéfficient de régression $R²$ rend compte de la qualité du modèle pour de nouvelles données à prédire, que le modèle n'a pas eu à traiter dans sa phase d'entrainement.

# %%
print("R² score pour le temps initial := %0.4f" % r2_score(YTest.iloc[:, 0], history.model.predict(XTest)[:, 0]))
print("R² score pour la velocité := %0.4f" % r2_score(YTest.iloc[:, 1], history.model.predict(XTest)[:, 1]))
print("R² score pour le temps final := %0.4f" % r2_score(YTest.iloc[:, 2], history.model.predict(XTest)[:, 2]))
# Out:
# R² score pour le temps initial := 0.9682
# R² score pour la velocité := 0.9379
# R² score pour le temps final := 0.9378

# %%
plt.figure(figsize=(10, 8))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.plot(history.history['mse'], "b-", lw=2, label="entrainement")
plt.plot(history.history['val_mse'], "r-", lw=2, label="validation")
plt.xlabel('Epoques', fontsize=12, fontweight="bold")
plt.ylabel('Mean Square Error', fontsize=12, fontweight="bold")
plt.legend(loc="upper right", fontsize=12)
plt.ylim(0, 4)
plt.show()

# %% [markdown]
# Prédiction du modèle pour la base dite de test pour le logarithme du temps $t_0$.

# %%
plt.figure(figsize=(10, 8))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.scatter(YTest.iloc[:, 0], history.model.predict(XTest)[:, 0], c="mediumblue", s=20,
            label="prediction")
plt.plot([min(YTest.iloc[:, 0]), max(YTest.iloc[:, 0])],
         [min(YTest.iloc[:, 0]), max(YTest.iloc[:, 0])], 'r-',
         label="prédiction parfaite")
plt.xlabel('Valeurs originelles', fontsize=12, fontweight="bold")
plt.ylabel('Valeurs prédites', fontsize=12, fontweight="bold")
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %% [markdown]
# Prédiction du modèle pour la base dite de test pour le logarithme de la vitesse $V_0$.

# %%
plt.figure(figsize=(10, 8))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.scatter(YTest.iloc[:, 1]+minval, history.model.predict(XTest)[:, 1]+minval, c="mediumblue", s=20,
            label="prediction")
plt.plot([min(YTest.iloc[:, 1]+minval), max(YTest.iloc[:, 1]+minval)],
         [min(YTest.iloc[:, 1]+minval), max(YTest.iloc[:, 1]+minval)], 'r-',
         label="prédiction parfaite")
plt.xlabel('Valeurs originelles', fontsize=12, fontweight="bold")
plt.ylabel('Valeurs prédites', fontsize=12, fontweight="bold")
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %% [markdown]
# Prédiction du modèle pour la base dite de test pour le logarithme de la vitesse $t_1$.

# %%
plt.figure(figsize=(10, 8))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.scatter(YTest.iloc[:, 2], history.model.predict(XTest)[:, 2], c="mediumblue", s=20,
            label="prediction")
plt.plot([min(YTest.iloc[:, 2]), max(YTest.iloc[:, 2])],
         [min(YTest.iloc[:, 2]), max(YTest.iloc[:, 2])], 'r-',
         label="prédiction parfaite")
plt.xlabel('Valeurs originelles', fontsize=12, fontweight="bold")
plt.ylabel('Valeurs prédites', fontsize=12, fontweight="bold")
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %% [markdown]
# ##### Analyse de sensitivté

# %% [markdown]
# Une analyse de sensitivité du modèle permet de donner la variation de la sortie en fonction de la variation des paramètres d'entrée du modèle. Ces indices donnent les paramètres les plus influents pour la prédiction des sorties. Pour cela, on utilise les indices de Sobol [[2]](https://tel.archives-ouvertes.fr/tel-01347105/document) :
#
# <center> $S_i := \frac{Var[E(Y|X_i)]}{Var[Y]}$ </center>
#
# <br>
# où $i$ représente la $i-ème$ variable d'entrée.

# %%
plt.figure(figsize=(12, 7))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
var_init = ['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']
plt.bar([i-0.5 for i in [0,5-1,10-1,15-1,20-1]],
        [np.var(Train.groupby(i)['Y0'].mean()) / np.var(Train['Y0']) for i in var_init],
        1, label='Indices de Sobol de $1^{er}$ ordre sur $t_0$', color='mediumblue')
plt.bar([i+0.5 for i in [0,5-1,10-1,15-1,20-1]],
        [np.var(Train.groupby(i)['Y1'].mean()) / np.var(Train['Y1']) for i in var_init],
        1, label='Indices de Sobol de $1^{er}$ ordre sur $V_0$', color='red')
plt.bar([i+1.5 for i in [0,5-1,10-1,15-1,20-1]],
        [np.var(Train.groupby(i)['Y2'].mean()) / np.var(Train['Y2']) for i in var_init],
        1, label='Indices de Sobol de $1^{er}$ ordre sur $t_1$', color='yellow')

for i,j in zip(var_init, [0,5-1,10-1,15-1,20-1]):
    plt.annotate(str(round(np.var(Train.groupby(i)['Y0'].mean()) / np.var(Train['Y0'])*100, 1))+"%",
                 xy=(j-1.1,
                     np.var(Train.groupby(i)['Y0'].mean()) / np.var(Train['Y0'])+0.01),
                 fontweight='bold', color="black", fontsize=9)
    plt.annotate(str(round(np.var(Train.groupby(i)['Y1'].mean()) / np.var(Train['Y1'])*100, 1))+"%",
                 xy=(j-0.1,
                     np.var(Train.groupby(i)['Y1'].mean()) / np.var(Train['Y1'])+0.01),
                 fontweight='bold', color="black", fontsize=9)
    plt.annotate(str(round(np.var(Train.groupby(i)['Y2'].mean()) / np.var(Train['Y2'])*100, 1))+"%",
                 xy=(j+0.9,
                     np.var(Train.groupby(i)['Y2'].mean()) / np.var(Train['Y2'])+0.01),
                 fontweight='bold', color="black", fontsize=9)
_=plt.xticks([0,5-1,10-1,15-1,20-1], labels=['Pressure', "NFace", "NFace_c", "Pixels", "Centre"], fontsize=15,
            fontweight="bold")
_=plt.legend(fontsize=8, bbox_to_anchor=(0.8,0.95))
plt.show()

# %% [markdown]
# ##### Comparaison avec la structure initial globale
# A partir de ces données prédites pour une structure, il est possible de comparer une approximation de la saturation et vélocité totale de la structure en moyennant sur l'ensemble de ses pores, et de pouvoir comparer avec la véritable valeur. Pour ce faire, on utilise l'approximation suivante :
# <br><br>
# <center> $v_0 = \frac{s_1-s_0}{t_1-t_0} $</center>
# <br><br>
# En effet, on peut assimiler la courbe de saturation à son coéfficient de régression, qui n'est nulle autre que la vélocité étudiée (au logarithme près) entre $t_0$ et $t_1$.
# <br>
# En utilisant les logarithmes prédit, on tente de retrouver $s_1$, où il suffit de rajouter $5\%$ de la valeur initiale à celle prédite car le calcul de $s_0$ s'est fait à partir du moment où la courbe dépassée $5\%$ de la valeur au temps 0. Au total, il y a 5 structures (une par pression).

# %%
real1, real2 =[], []
fake1, fake2 = [], []
for p in [0.5,1,2,4,8]:
    t=X[X['Pressure'] == p]
    real1.append(np.mean(t['Y3'])+0.05)
    real2.append(np.mean([np.exp(i+minval) for i in t['Y1']]))

    toTest = scaler.transform(X[X['Pressure'] == p][['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']])

    v0_pred=[np.exp(i+minval) for i in history.model.predict(toTest)[:, 1]]
    t0_pred=[np.exp(i) for i in history.model.predict(toTest)[:, 0]]
    t1_pred=[np.exp(i) for i in history.model.predict(toTest)[:, 2]]

    s_pred = [i*(j-k) for i,j,k in zip(v0_pred,t1_pred,t0_pred)]

    fake1.append(np.mean(s_pred)+0.1)
    fake2.append(np.mean(v0_pred))

# %% [markdown]
# Pour la saturation globale de l'électrode.

# %%
plt.figure(figsize=(12, 7))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
var_init = ['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']
plt.bar([1,4,7,10,13], real1, width=1, color="mediumblue", label='saturation initiale')
plt.bar([2,5,8,11,14], fake1, width=1, color="red",
        label='saturation approximée')
_=plt.xticks([1.5, 4.5, 7.5, 10.5, 13.5], labels=['Pressure : 0.5', "Pressure : 1", "Pressure : 2",
                                             "Pressure : 4", "Pressure : 8"], fontsize=15,
            fontweight="bold", rotation=25)
_=plt.yticks(fontsize=15)
_=plt.legend(fontsize=12)

# %% [markdown]
# Pour la vélocité globale de l'electrode.

# %%
plt.figure(figsize=(12, 7))
ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
var_init = ['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']
plt.bar([1,4,7,10,13], real2, width=1, color="mediumblue", label='velocité initiale')
plt.bar([2,5,8,11,14], fake2, width=1, color="red",
        label='vélocité approximée')
_=plt.xticks([1.5, 4.5, 7.5, 10.5, 13.5], labels=['Pressure : 0.5', "Pressure : 1", "Pressure : 2",
                                             "Pressure : 4", "Pressure : 8"], fontsize=15,
            fontweight="bold", rotation=25)
_=plt.yticks(fontsize=15)
_=plt.legend(fontsize=12)

# %% [markdown]
# ##### Sauvergarde des ressources nécessaires au modèle

# %%
model.save("./ressources/validated_model")

with open('./ressources/scaler.pkl', 'wb') as f:
                pickle.dump(scaler, f)
with open('./ressources/shift.pkl', 'wb') as f:
                pickle.dump(np.array(minval), f)
# Out:
# WARNING:tensorflow:From /home/marc/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./ressources/validated_model/assets

# %% [markdown]
# ##### Utiliser le modèle ultérieurement

# %% [markdown]
# Afin de pouvoir utiliser le modèle, il est important d'avoir :
# - le modèle entrainé.
# - la fonction de normalisation des variables d'entrées.
# - la valeur minimale de la distribution de la transformation pour la vélocité, afin de prédire la valeur shiftée.

# %%
model_to_be_used = tf.keras.models.load_model("./validated_model")
with open('../ressources/scaler.pkl', 'rb') as f:
                scaler = pickle.load(f)
with open('../ressources/shift.pkl', 'rb') as f:
                minval_shift = pickle.load(f)

# %% [markdown]
# ##### Export des prédictions pour une étude visuelle
# Les prédictions du modèle sont exportées afin d'être utilisée par une personne effectuant des simulations, afin de visualiser les résultats sans avoir à lancer des calculs gourmands en temps et en ressources.

# %%
Pred = pd.DataFrame(history.model.predict(
    scaler.transform(X[['Pressure', 'Pixels', 'NFace', 'NFace_c', 'Centre']])),
                    columns=['Y0_pred', 'Y1_pred', 'Y2_pred'])
Pred['Y1_pred'] = [i+minval for i in Pred['Y1_pred']]
Pred['Y0_pred_exp'] = [np.exp(i) for i in Pred['Y0_pred']]
Pred['Y1_pred_exp'] = [np.exp(i) for i in Pred['Y1_pred']]
Pred['Y2_pred_exp'] = [np.exp(i) for i in Pred['Y2_pred']]
Pred['Y3_pred_exp'] = [i*(j-k)+0.05 for i,j,k in zip(Pred['Y1_pred_exp'], Pred['Y2_pred_exp'],
                                                     Pred['Y0_pred_exp'])]

# %%
# zer = pd.DataFrame(columns=['File','Pressure','ID', 'Pixels', 'NFace', 'NFace_c', 'Ratio', 'Centre'])
# for path in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'):
#     for file in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"):

#         if 'velocity_per_pore' in file:
            
#             with open('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"+file, 'rb') as f:
#                 data = pickle.load(f)
                
#             for col in range(data.shape[0]):
                
#                 zer.loc[len(zer)] = [file.split(".")[0], float(path.split("press")[1])] + \
#                 data[["Id", "npx", "nface", "nface_c", "ratio", "centre"]].iloc[col, :].tolist()

# %%
# y2 = []
# for path in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'):
#     for file in os.listdir('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"):

#         if 'saturation' in file:

#             with open('/media/marc/My Passport/Marc/Teletravail/Oier/ressources/Data_for_Marc/'+path+"/"+file, 'rb') as f:
#                 saturation = pickle.load(f).iloc[:,1:]

#             for col in range(saturation.shape[1]):

#                 t0=next((i for i,
#                          x in enumerate(saturation.iloc[:,col]) if abs(x-saturation.iloc[0,col]) >= 0.05),
#                         None)
#                 t1=next((i for i, 
#                          x in enumerate(saturation.iloc[:,col]) if abs(x-saturation.iloc[-1,col]) <= 0.05),None)
#                 if saturation.iloc[-1,col] >= 0.99:
#                     out=1
#                 else:
#                     out=0

#                 try:

#                     y2.append([t0, t1, out, saturation.iloc[t1,col],
#                                      (saturation.iloc[t1,col] - saturation.iloc[t0,col]) / (t1-t0)])
#                 except:

#                     y2.append([t0, t1, out, saturation.iloc[-1,col], "Error"])

# y2 = pd.DataFrame(y2)

# %%
# zer['Y0'] = y2.iloc[:, 0]
# zer['Y1'] = y2.iloc[:, 4]
# zer['Y2'] = y2.iloc[:, 1]
# zer['Y3'] = y2.iloc[:, 3]

# idx=[]
# for i in range(zer.shape[0]):
#     if "nan" != str(zer.iloc[i,9]):
#         idx.append(i)
# zer =zer.iloc[idx, :]
# zer=zer[zer['Y1'] != "Error"]

# %%
# toOier = pd.concat([zer[["File","Pressure","ID","Pixels","NFace","NFace_c","Ratio","Centre","Y0","Y1","Y2"]].reset_index(drop=True),
# Pred[["Y0_pred","Y1_pred","Y2_pred","Y0_pred_exp","Y1_pred_exp","Y2_pred_exp"]].reset_index(drop=True)], axis=1, ignore_index=True)

# %%
# toOier.columns = ["File","Pressure","ID","Pixels","NFace","NFace_c","Ratio","Centre","Y0","Y1","Y2"] + \
# ["Y0_pred","Y1_pred","Y2_pred","Y0_pred_exp","Y1_pred_exp","Y2_pred_exp"]

# %%
# with open('./ToOier.pkl', 'wb') as f:
#                pickle.dump(toOier, f)
